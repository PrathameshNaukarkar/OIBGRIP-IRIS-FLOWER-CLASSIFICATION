# %% [markdown]
# ### Name:Prathamesh Naukarkar
# ### Task:Iris flower Identification

# %% [markdown]
# ### Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
data.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
plt.figure(figsize=(8 ,4))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
plt.show()

# %%
LE=LabelEncoder()

# %%
data['Species']=LE.fit_transform(df['Species'])
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
X=data.iloc[:, 1:5]
X.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y=data.iloc[:,-1:]
y.head()
# Out:
#    Species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=44)
print("X_train")
print(X_train.head())
print("X_test")
print(X_test.head())
print("y_train")
print(y_train.head())
print("y_test")
print(y_test.head())
print("__________________________")
# Out:
# X_train
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 123            6.3           2.7            4.9           1.8
# 80             5.5           2.4            3.8           1.1
# 43             5.0           3.5            1.6           0.6
# 6              4.6           3.4            1.4           0.3
# 112            6.8           3.0            5.5           2.1
# X_test
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 144            6.7           3.3            5.7           2.5
# 9              4.9           3.1            1.5           0.1
# 79             5.7           2.6            3.5           1.0
# 95             5.7           3.0            4.2           1.2
# 104            6.5           3.0            5.8           2.2
# y_train
#      Species
# 123        2
# 80         1
# 43         0
# 6          0
# 112        2
# y_test
#      Species
# 144        2
# 9          0
# 79         1
# 95         1
# 104        2
# ...

# %% [markdown]
# ### Data Visualization (Several Type of Possible Plots)

# %%
sns.lmplot( x="SepalLengthCm", y="SepalWidthCm", data=data, fit_reg=False, hue='Species', legend=False)
plt.legend(loc='lower right')
plt.show()

# %%
sns.lmplot( x="PetalLengthCm", y="PetalWidthCm", data=data, fit_reg=False, hue='Species', legend=False)
plt.legend(loc='lower right')
plt.show()

# %%
plt.figure(figsize=(8 ,4))
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=data["SepalLengthCm"])
plt.show()

# %%
plt.figure(figsize=(8 ,4))
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=data["SepalWidthCm"])
plt.show()

# %%
plt.figure(figsize=(8 ,4))
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=data["PetalLengthCm"])
plt.show()

# %%
plt.figure(figsize=(8 ,4))
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x=data["PetalWidthCm"])
plt.show()

# %%
plt.figure(figsize=(8 ,4))
sns.boxplot(data=data, orient="h", palette="Set2")
plt.show()

# %%
plt.figure(figsize=(8 ,4))
plt.plot(data.Id, data["SepalLengthCm"], "blue")
plt.show()

# %%
plt.figure(figsize=(8 ,4))
plt.plot(data.Id, data["SepalLengthCm"], "r--")
plt.show()

# %%
data.plot(kind ="scatter", x ='SepalLengthCm',y ='PetalLengthCm')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.FacetGrid(df, hue ="Species",height = 5).map(plt.scatter,'SepalLengthCm','PetalLengthCm').add_legend()
sns.set()

# %%
data.hist()
plt.show()

# %%
plt.figure
data['SepalLengthCm'].hist()
plt.show()

# %%
plt.figure
data['PetalLengthCm'].hist()
plt.show()

# %%
plt.figure
data['SepalWidthCm'].hist()
plt.show()

# %%
plt.figure
data['PetalWidthCm'].hist()
plt.show()

# %%
data.plot.pie(subplots=True)
plt.show()

# %%
data.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.plot.area()
# Out:
# <AxesSubplot:>

# %%
data.plot.scatter(x='SepalLengthCm', y='PetalLengthCm')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
data.plot.hexbin(x ='SepalWidthCm', y ='PetalWidthCm', gridsize = 18)
plt.show()

# %%
model=SVC()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([2, 0, 1, 1, 2, 0, 2, 2, 2, 1, 0, 1, 0, 2, 0, 0, 2, 1, 0, 2, 1, 2,
#        2, 1, 2, 1, 0, 1, 0, 1, 0, 1, 1, 2, 0, 1, 0, 0])

# %%
A=accuracy_score(y_test, y_pred)
A
# Out:
# 0.9736842105263158

# %%
import sklearn.externals
import joblib
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
